# %%
# !gdown 1KtsneeRtxctLYz3ksq1ccOxc9XNuOguE
# !unzip /content/BinaryNet.pytorch-master.zip
# !rm -rf /content/__MACOSX

# %%
# !pip install torch
# !pip install torchvision
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !python /content/BinaryNet.pytorch-master/main_binary.py --model alexnet --save alexnet_cnn --dataset cifar10 --epochs 50
# Out:
# saving to ./results/alexnet_cnn
# creating model alexnet
# created model with configuration: {'input_size': None, 'dataset': 'cifar10'}
# number of parameters: 61110184
# ...
# 170499072it [00:01, 95140758.40it/s]
# Extracting /content/Datasets/CIFAR10/cifar-10-python.tar.gz to /content/Datasets/CIFAR10
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Files already downloaded and verified
# training regime: {0: {'optimizer': 'SGD', 'lr': 0.01, 'weight_decay': 0.0005, 'momentum': 0.9}, 10: {'lr': 0.005}, 15: {'lr': 0.001, 'weight_decay': 0}, 20: {'lr': 0.0005}, 25: {'lr': 0.0001}}
# ...

# %%
# !python /content/BinaryNet.pytorch-master/main_binary.py --model resnet --save resnet18_cnn --dataset cifar10 --epochs 50
