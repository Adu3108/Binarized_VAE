# %% [markdown]
# **Version History**
#
# Binary_VAE_v1 :- All layers binarized (LeakyReLU activation)
#
# Binary_VAE_v2 :- Only linear layers binarized (Hardtanh activation)
#
# Binary_VAE_v3 :- All layers binarized (Hardtanh activation)
#
# Binary_VAE_v4 :- Only encoder layers binarized (Hardtanh activation)

# %% [markdown]
# **Cloning Git repository**

# %%
# !git clone https://github.com/Adu3108/Binarized_VAE.git
# Out:
# Cloning into 'Binarized_VAE'...
# remote: Enumerating objects: 9277, done.
# remote: Counting objects: 100% (3181/3181), done.
# remote: Compressing objects: 100% (3171/3171), done.
# remote: Total 9277 (delta 8), reused 3180 (delta 8), pack-reused 6096
# Receiving objects: 100% (9277/9277), 147.00 MiB | 26.25 MiB/s, done.
# Resolving deltas: 100% (11/11), done.
# Checking out files: 100% (9157/9157), done.

# %% [markdown]
# **Extracting the necessary code**

# %%
# !mv /content/Binarized_VAE/First\ VAE/Binarized\ Version/binarized_modules.py /content/
#!mv /content/Binarized_VAE/First\ VAE/Binarized\ Version/Binary_bvae.py /content/ # Version 1 with all binarized layers
# !mv /content/Binarized_VAE/First\ VAE/Binarized\ Version/Binary_bvae_v2.py /content/ # Version 2 with only binarized linear layers and hardtanh activation
#!mv /content/Binarized_VAE/First\ VAE/Binarized\ Version/Binary_bvae_v3.py /content/ # Version 3
#!mv /content/Binarized_VAE/First\ VAE/Binarized\ Version/Binary_bvae_v4.py /content/ # Version 4

# %% [markdown]
# **Install all the dependencies**

# %%
# !pip install torch 
# !pip install torchvision
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# **Install the dataset**

# %% [markdown]
# **MNIST Dataset**

# %%
# !mv /content/Binarized_VAE/Datasets/MNIST\ Dataset\ JPG\ format.zip /content/

# %% [markdown]
# **Preprocessing of Dataset**
#
# There will be 2 directories :-
# 1.   Training
# 2.   Testing
#
# Each directory consists of 10 classes named 0,1,2,...,9
#
# Each class contains 10 images

# %%
import os

os.rename('/content/MNIST Dataset JPG format.zip','MNIST.zip')

# %%
# !jar xvf /content/MNIST.zip
# Out:
# Streaming output truncated to the last 5000 lines.
# extracted: MNIST Dataset JPG format/MNIST - JPG - training/9/1820.jpg
# extracted: MNIST Dataset JPG format/MNIST - JPG - training/9/18211.jpg
# extracted: MNIST Dataset JPG format/MNIST - JPG - training/9/18228.jpg
# extracted: MNIST Dataset JPG format/MNIST - JPG - training/9/18241.jpg
# extracted: MNIST Dataset JPG format/MNIST - JPG - training/9/18251.jpg
# extracted: MNIST Dataset JPG format/MNIST - JPG - training/9/1826.jpg
# extracted: MNIST Dataset JPG format/MNIST - JPG - training/9/18277.jpg
# extracted: MNIST Dataset JPG format/MNIST - JPG - training/9/18296.jpg
# extracted: MNIST Dataset JPG format/MNIST - JPG - training/9/183.jpg
# extracted: MNIST Dataset JPG format/MNIST - JPG - training/9/18350.jpg
# extracted: MNIST Dataset JPG format/MNIST - JPG - training/9/18355.jpg
# extracted: MNIST Dataset JPG format/MNIST - JPG - training/9/18374.jpg
# extracted: MNIST Dataset JPG format/MNIST - JPG - training/9/18377.jpg
# ...

# %%
os.rename('/content/MNIST Dataset JPG format', 'MNIST')
os.rename('/content/MNIST/MNIST - JPG - training','/content/MNIST/Training')
os.rename('/content/MNIST/MNIST - JPG - testing', '/content/MNIST/Testing')

# %%
os.chdir('/content/MNIST/Training')
arr = os.listdir()
for i in arr:
  tmp = os.path.join('/content/MNIST/Training',i)
  os.chdir(tmp)
  rem = os.listdir()[10:]
  for j in rem:
    os.remove(j)
os.chdir('/content/MNIST/Testing')
arr = os.listdir()
for i in arr:
  tmp = os.path.join('/content/MNIST/Testing',i)
  os.chdir(tmp)
  rem = os.listdir()[10:]
  for j in rem:
    os.remove(j)
os.chdir('/content')

# %% [markdown]
# **Caltech-101 Dataset**

# %%
# !mv /content/Binarized_VAE/Datasets/Caltech-101 /content/

# %%
import os

os.mkdir('/content/Dataset')
os.mkdir('/content/Dataset/Training')
os.mkdir('/content/Dataset/Testing')
os.mkdir('/content/Dataset/Validation')
os.chdir("/content/Caltech-101/")
l = os.listdir()
os.chdir('/content/Dataset/Training')
for i in l:
  path = os.path.join('/content/Dataset/Training',i)
  os.mkdir(path)
os.chdir('/content/Dataset/Validation')
for i in l:
  path = os.path.join('/content/Dataset/Validation',i)
  os.mkdir(path)  
os.chdir('/content/Dataset/Testing')
for i in l:
  path = os.path.join('/content/Dataset/Testing',i)
  os.mkdir(path)

# %% [markdown]
# **Preprocessing of Caltech-101 Dataset**
#
# There will be 3 directories :-
# 1.   Training
# 2.   Validation
# 1.   Testing
#
# Each directory consists of 102 classes
#
# Each class contains 10 images

# %%
for i in l:
  path = os.path.join('/content/Caltech-101/',i)
  os.chdir(path)
  training = os.listdir()[:10]
  validation = os.listdir()[10:20]
  testing = os.listdir()[20:30]
  rem = os.listdir()[30:]
  for j in training:
    original_path = os.path.join(path,j)
    val_path = os.path.join('/content/Dataset/Training',i)
    val_path = os.path.join(val_path,j)
    os.replace(original_path,val_path)
  for j in validation:
    original_path = os.path.join(path,j)
    val_path = os.path.join('/content/Dataset/Validation',i)
    val_path = os.path.join(val_path,j)
    os.replace(original_path,val_path)
  for j in testing:
    original_path = os.path.join(path,j)
    val_path = os.path.join('/content/Dataset/Testing',i)
    val_path = os.path.join(val_path,j)
    os.replace(original_path,val_path)
  for j in rem:
    os.remove(j)
  os.chdir('/content')

# %% [markdown]
# **Training**

# %% [markdown]
# **MNIST Dataset**

# %%
# !python Binary_bvae.py train --grayscale --beta 1 --n_latent 30 --dimensions 28x28 --dataset /content/MNIST/Training
# !python Binary_bvae_v2.py train --grayscale --beta 1 --n_latent 30 --dimensions 28x28 --dataset /content/MNIST/Training
# !python Binary_bvae_v3.py train --grayscale --beta 1 --n_latent 30 --dimensions 28x28 --dataset /content/MNIST/Training
# !python Binary_bvae_v4.py train --grayscale --beta 1 --n_latent 30 --dimensions 28x28 --dataset /content/MNIST/Training

# %% [markdown]
# **Caltech-101 Dataset**

# %%
# !python Binary_bvae.py train --beta 1 --n_latent 30 --dimensions 28x28 --dataset /content/Dataset/Training
# !python Binary_bvae_v2.py train --beta 1 --n_latent 30 --dimensions 28x28 --dataset /content/Dataset/Training
# !python Binary_bvae_v3.py train --beta 1 --n_latent 30 --dimensions 28x28 --dataset /content/Dataset/Training
# !python Binary_bvae_v4.py train --beta 1 --n_latent 30 --dimensions 28x28 --dataset /content/Dataset/Training

# %% [markdown]
# **Preprocessing of Weights file**

# %%
for root, dirs, files in os.walk('/content'):
    for file in files:
        if file.endswith('.pt'):
            weights = root+'/'+str(file)
os.rename(weights, '/content/weights.pt')

# %%
# %matplotlib inline
# %matplotlib notebook

# %% [markdown]
# **Fixing the final directory structure**

# %%
# !mkdir Results
# !mkdir /content/Results/Input
# !mkdir /content/Results/Reconstructed

# %% [markdown]
# **Reconstruction**

# %% [markdown]
# **MNIST Dataset**

# %%
#!python Binary_bvae.py test --grayscale --beta 1 --n_latent 30 --dimensions 28x28 --dataset /content/MNIST/Testing --weights /content/weights.pt
# !python Binary_bvae_v2.py test --grayscale --beta 1 --n_latent 30 --dimensions 28x28 --dataset /content/MNIST/Testing --weights /content/weights.pt
#!python Binary_bvae_v3.py test --grayscale --beta 1 --n_latent 30 --dimensions 28x28 --dataset /content/MNIST/Testing --weights /content/weights.pt
#!python Binary_bvae_v4.py test --grayscale --beta 1 --n_latent 30 --dimensions 28x28 --dataset /content/MNIST/Testing --weights /content/weights.pt

# %% [markdown]
# **Caltech-101 Dataset**

# %%
#!python Binary_bvae.py test --beta 1 --n_latent 30 --dimensions 28x28 --dataset /content/Dataset/Testing --weights /content/weights.pt
# !python Binary_bvae_v2.py test --beta 1 --n_latent 30 --dimensions 28x28 --dataset /content/Dataset/Testing --weights /content/weights.pt
#!python Binary_bvae_v3.py test --beta 1 --n_latent 30 --dimensions 28x28 --dataset /content/Dataset/Testing --weights /content/weights.pt
#!python Binary_bvae_v4.py test --beta 1 --n_latent 30 --dimensions 28x28 --dataset /content/Dataset/Testing --weights /content/weights.pt

# %% [markdown]
# **Comparison between original image and reconstructed image**

# %%
os.chdir('/content/Results/Input')
inputs = os.listdir()
inputs.sort()
inputs = inputs[1:]
os.chdir('/content/Results/Reconstructed')
outputs = os.listdir()
outputs.sort()
outputs = outputs[1:]
os.chdir('/content')

# %%
# !mv /content/Binarized_VAE/Datasets/Screenshot\ 2022-06-15\ at\ 4.58.08\ PM.png /content/
os.rename('/content/Screenshot 2022-06-15 at 4.58.08 PM.png','/content/white.png')

# %%
import cv2
from google.colab.patches import cv2_imshow

white = cv2.imread('white.png')
errorfile = open("/content/Results/errors.txt","r+")
errors = errorfile.readlines()
for i in range(len(inputs)):
  input_path = os.path.join('/content/Results/Input',inputs[i])
  output_path = os.path.join('/content/Results/Reconstructed',outputs[i])
  img1 = cv2.imread(input_path)
  img2 = cv2.imread(output_path)
  scale_percent = 500 # percent of original size
  width1 = int(img1.shape[1] * scale_percent / 100)
  height1 = int(img1.shape[0] * scale_percent / 100)
  dim1 = (width1, height1)
  width2 = int(img2.shape[1] * scale_percent / 100)
  height2 = int(img2.shape[0] * scale_percent / 100)
  dim2 = (width2, height2)

  resized1 = cv2.resize(img1, dim1, interpolation = cv2.INTER_AREA)
  resized2 = cv2.resize(img2, dim2, interpolation = cv2.INTER_AREA)

  im_v = cv2.hconcat([resized1, white, resized2])

  cv2_imshow(im_v)
  print(errors[i])
